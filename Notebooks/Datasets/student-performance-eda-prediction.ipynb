# %% [markdown]
# Hi!

# %% [markdown]
# This is my first Kernel, hope you'll love it!

# %% [markdown]
# For questions and remarks - please write me a comment.

# %% [markdown]
# For those interested in looking at the full notebook - https://github.com/NadavKiani/Students-Performance-in-Exams

# %% [markdown]
# # Student Performence in Exams - Writing Score

# %%
# Import Libreries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('StudentsPerformance.csv')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Some statistics about the data

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# We can see that there are no missing values

# %% [markdown]
# Now let's convert the data to numeric so the machine learning algorithms could be trained and make predictions.

# %%
data['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
sns.catplot(x='gender',kind='count',data=data,height=4.5,palette='viridis')
plt.title('Gender')
# Out:
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Gender')

# %%
data['gender'].replace({'male':'0','female':'1'},inplace=True)

# %%
data['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
data["race/ethnicity"].sort_values()
sns.catplot(x='race/ethnicity',kind='count',data=data,height=4.5,palette='viridis',
            order=['group A','group B','group C','group D','group E'])
# Out:
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# # Create Column Transformer with 3 types of transformers
# num_features = X.select_dtypes(exclude="object").columns
# cat_features = X.select_dtypes (include="object").columns
# from sklearn.preprocessing import OneHotEncoder, StandardScaler
# from sklearn.compose import Column Transformer
# numeric_transformer = StandardScaler ()
# oh_transformer = OneHotEncoder ()
# preprocessor = Column Transformer (
# [
# ("OneHotEncoder", oh_transformer, cat_features,
# | ("StandardScaler", numeric_transformer, num_features),
# )

# %%
# # Create an Evaluate Function to give all metrics after model Training
# def evaluate_model(true, predicted):
#     mae = mean_absolute_error(true, predicted)
#     mse = mean_squared_error(true, predicted)
#     rmse = np.sqrt(mean_squared_error(true, predicted))
#     r2_square= r2_score(true, predicted)
#     return mae, rmse, r2_square

# %%
data.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
data['race/ethnicity'].replace({'group A':'1','group B':'2', 'group C':'3',
                               'group D':'4','group E':'5'},inplace=True)

# %%
data['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
sns.catplot(x='lunch',kind='count',data=data,height=4.5,palette='viridis')
# Out:
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
data['lunch'].replace({'free/reduced':'0','standard':'1'},inplace=True)

# %%
data['test preparation course'].value_counts()
# Out:
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %%
sns.catplot(x='test preparation course',kind='count',data=data,height=4.5,palette='viridis')
# Out:
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
data['test preparation course'].replace({'none':'0','completed':'1'},inplace=True)

# %%
data['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
data["race/ethnicity"].sort_values()
sns.catplot(x='parental level of education',kind='count',data=data,height=4.5,aspect=2,palette='viridis',
            order=["some high school","high school","associate's degree","some college",
                   "bachelor's degree","master's degree"],)
# Out:
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
data['parental level of education'].replace({'some high school':'1','high school':'1',"associate's degree":'2',
                                        'some college':'3',"bachelor's degree":'4',"master's degree":'5'},inplace=True)

# %%
data.head()
# Out:
#   gender race/ethnicity parental level of education lunch  \
# 0      1              2                           4     1
# 1      1              3                           3     1
# 2      1              2                           5     1
# 3      0              1                           2     0
# 4      0              3                           3     1
#
#   test preparation course  math score  reading score  writing score
# 0                       0          72             72             74
# 1                       1          69             90             88
# 2                       0          90             95             93
# 3                       0          47             57             44
# 4                       0          76             78             75

# %% [markdown]
# Now, when all our fields are numeric, we can continue with the project and make some exploratory data analysis

# %% [markdown]
# ***

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Now we will look a little deeper on some interesting plots of our data, in order to get some insights

# %%
sns.set(rc={'figure.figsize':(20,6)})
sns.countplot(x='writing score', hue='test preparation course',data=data, palette='viridis')
plt.title('Writing Score by Test Preparation Course')
# Out:
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Writing Score by Test Preparation Course')

# %% [markdown]
# We can see from this plot that most of the students who got a high score at the writing test, __study__ at the test preparation course. We can understand that the preparation course is __helping__ the students at the writing test

# %% [markdown]
# ***

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='math score',y='reading score', hue='gender',data=data, palette='viridis')
plt.title('Math score VS Readind Score by Gender')
# Out:
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Math score VS Readind Score by Gender')

# %% [markdown]
# We can see that there is a __nice correlation__ between the math score and the reading score. We can also see that __female__ (Green) has a better score at the reading exams

# %% [markdown]
# ***

# %%
# Take a look at our objectives distribution
plt.figure(figsize=(8, 4))
plt.hist(x='writing score',bins=10,data=data)
# Out:
# (array([  2.,   6.,  14.,  55., 126., 161., 223., 225., 120.,  68.]),
#  array([ 10.,  19.,  28.,  37.,  46.,  55.,  64.,  73.,  82.,  91., 100.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# We can see that the scores distribution is a __Normal distrution__, where most of the student's score is between __65 to 80__

# %% [markdown]
# ***

# %%
sns.set(rc={'figure.figsize':(20,6)})
sns.countplot(x='writing score', hue='lunch',data=data, palette='viridis')
# Out:
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='writing score', ylabel='count'>

# %% [markdown]
# We can see that the students who __ate lunch__, had a __better__ score at the writing test.

# %% [markdown]
# ***

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Linear Regression##

# %% [markdown]
# We will first split the data to our predictors variables and our criterion variable

# %%
X = data[['gender','race/ethnicity','parental level of education','lunch','test preparation course','math score','reading score']]

# %%
y = data['writing score']

# %%
# Split the data to train and test
from sklearn import model_selection
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# implementation of Linear Regression model using scikit-learn and K-fold for stable model
from sklearn.linear_model import LinearRegression
kfold = model_selection.KFold(n_splits=10)
lr = LinearRegression()
scoring = 'r2'
results = model_selection.cross_val_score(lr, X, y, cv=kfold, scoring=scoring)
lr.fit(X_train,y_train)
lr_predictions = lr.predict(X_test)
print('Coefficients: \n', lr.coef_)
# Out:
# Coefficients:
#  [5.58898699 0.12448853 0.8098734  0.398649   3.29932733 0.26098698
#  0.68227153]

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, lr_predictions))
print('MSE:', metrics.mean_squared_error(y_test, lr_predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, lr_predictions)))
# Out:
# MAE: 2.8321613399573757
# MSE: 12.511374729119412
# RMSE: 3.5371421697635244

# %%
from sklearn.metrics import r2_score
print("R_square score: ", r2_score(y_test,lr_predictions))
# Out:
# R_square score:  0.9442154097066041

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ## Decision Trees

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(random_state = 42)
dtr.fit(X_train,y_train)
dtr_predictions = dtr.predict(X_test) 

# R^2 Score
print("R_square score: ", r2_score(y_test,dtr_predictions))
# Out:
# R_square score:  0.854720369284225

# %% [markdown]
# ***

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators = 100)
rfr.fit(X_train,y_train)
rfr_predicitions = rfr.predict(X_test) 

# R^2 Score
print("R_square score: ", r2_score(y_test,rfr_predicitions))
# Out:
# R_square score:  0.9258852575940375

# %% [markdown]
# ***

# %% [markdown]
# ## Gardient Boosting

# %%
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'ls')
clf.fit(X_train, y_train)
clf_predicitions = clf.predict(X_test) 
print("R_square score: ", r2_score(y_test,clf_predicitions))
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\Notebooks\Datasets\student-performance-eda-prediction.ipynb Cell 68 line 4
#       <a href='vscode-notebook-cell:/e%3A/ALL%20PROGRAMS/GIT%20HUB%20PROJECTS/Natural%20Language%20Processing/End%20to%20End%20Projects%20on%20GitHub/Git_Hub_Section/ML_project/Notebooks/Datasets/student-performance-eda-prediction.ipynb#Y124sZmlsZQ%3D%3D?line=0'>1</a> from sklearn import ensemble
#       <a href='vscode-notebook-cell:/e%3A/ALL%20PROGRAMS/GIT%20HUB%20PROJECTS/Natural%20Language%20Processing/End%20to%20End%20Projects%20on%20GitHub/Git_Hub_Section/ML_project/Notebooks/Datasets/student-performance-eda-prediction.ipynb#Y124sZmlsZQ%3D%3D?line=1'>2</a> clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
#       <a href='vscode-notebook-cell:/e%3A/ALL%20PROGRAMS/GIT%20HUB%20PROJECTS/Natural%20Language%20Processing/End%20to%20End%20Projects%20on%20GitHub/Git_Hub_Section/ML_project/Notebooks/Datasets/student-performance-eda-prediction.ipynb#Y124sZmlsZQ%3D%3D?line=2'>3</a>           learning_rate = 0.1, loss = 'ls')
# ----> <a href='vscode-notebook-cell:/e%3A/ALL%20PROGRAMS/GIT%20HUB%20PROJECTS/Natural%20Language%20Processing/End%20to%20End%20Projects%20on%20GitHub/Git_Hub_Section/ML_project/Notebooks/Datasets/student-performance-eda-prediction.ipynb#Y124sZmlsZQ%3D%3D?line=3'>4</a> clf.fit(X_train, y_train)
#       <a href='vscode-notebook-cell:/e%3A/ALL%20PROGRAMS/GIT%20HUB%20PROJECTS/Natural%20Language%20Processing/End%20to%20End%20Projects%20on%20GitHub/Git_Hub_Section/ML_project/Notebooks/Datasets/student-performance-eda-prediction.ipynb#Y124sZmlsZQ%3D%3D?line=4'>5</a> clf_predicitions = clf.predict(X_test)
#       <a href='vscode-notebook-cell:/e%3A/ALL%20PROGRAMS/GIT%20HUB%20PROJECTS/Natural%20Language%20Processing/End%20to%20End%20Projects%20on%20GitHub/Git_Hub_Section/ML_project/Notebooks/Datasets/student-performance-eda-prediction.ipynb#Y124sZmlsZQ%3D%3D?line=5'>6</a> print("R_square score: ", r2_score(y_test,clf_predicitions))
#
# File e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\sklearn\base.py:1144, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1139 partial_fit_and_fitted = (
#    1140     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1141 )
#    1143 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
#    1151     return fit_method(estimator, *args, **kwargs)
#
# File e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\sklearn\base.py:637, in BaseEstimator._validate_params(self)
#     629 def _validate_params(self):
#     630     """Validate types and values of constructor parameters
#     631
#     632     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     635     accepted constraints.
#     636     """
# --> 637     validate_parameter_constraints(
#     638         self._parameter_constraints,
#     639         self.get_params(deep=False),
#     640         caller_name=self.__class__.__name__,
#     641     )
#
# File e:\ALL PROGRAMS\GIT HUB PROJECTS\Natural Language Processing\End to End Projects on GitHub\Git_Hub_Section\ML_project\ML_env\lib\site-packages\sklearn\utils\_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'loss' parameter of GradientBoostingRegressor must be a str among {'squared_error', 'quantile', 'absolute_error', 'huber'}. Got 'ls' instead.

# %% [markdown]
# ***

# %% [markdown]
# Now we will show a comparison between all the models that we got

# %%
y = np.array([r2_score(y_test,lr_predictions),r2_score(y_test,dtr_predictions),r2_score(y_test,rfr_predicitions),
           r2_score(y_test,clf_predicitions)])
x = ["LinearRegression","RandomForest","DecisionTree","Grdient Boost"]
plt.bar(x,y)
plt.title("Comparison of Regression Algorithms")
plt.ylabel("r2_score")
plt.show()

# %% [markdown]
# The Linear Regression has the highest R^2 Score.
